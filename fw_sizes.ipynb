# %%
# %ls -l /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.*
# Out:
# -rwxr-xr-x 1 jos jos  334048 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.bin*
# -rw-r--r-- 1 jos jos 4849244 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.dis
# -rwxr-xr-x 1 jos jos 5865376 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.elf*
# -rw-r--r-- 1 jos jos 1769114 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.elf.map
# -rw-r--r-- 1 jos jos  939659 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.hex
# -rw-r--r-- 1 jos jos  668160 Oct  8 18:46 /home/jos/micropython/ports/rp2/build-RPI_PICO_py/firmware.uf2

# %% [markdown]
# ##### No Typing
#    text    data     bss     dec     hex filename
#  332704       0    5524  338228   52934 /home/builder/micropython/ports/rp2/build-RPI_PICO/firmware.elf
#
# #### C typing
#    text    data     bss     dec     hex filename
#  332704       0    5524  338228   52934 /home/builder/micropython/ports/rp2/build-RPI_PICO/firmware.elf
#
# ##### .py typing - frozen
#
#    text    data     bss     dec     hex filename
#  334048       0    5524  339572   52e74 /home/builder/micropython/ports/rp2/build-RPI_PICO/firmware.elf
#
# ##### .py typing - frozen -O3
#
#    text    data     bss     dec     hex filename
#  333792       0    5524  339316   52d74 /home/builder/micropython/ports/rp2/build-RPI_PICO_T/firmware.elf
#
# ##### .py typing - frozen -O3 - reduced
# no abc but including collections.abc
# removed the less useful reveal_type, get_origin, get_args from typing.py
#
#    text    data     bss     dec     hex filename
#  333596       0    5524  339120   52cb0 /home/builder/micropython/ports/rp2/build-RPI_PICO_T/firmware.elf

# %%
50 +  311 + 66 +  38 + 82
# Out:
# 547

# %%
333596 - 332704 

# 333700 - 332704 
# 334048 - 333700
# Out:
# 892

# %%
332704 - 332704
# Out:
# 0
